# %%
# %load_ext autoreload
# %autoreload 2

# %%
from cpga_analyzer import DataReader, Package
from cpga_analyzer.cpga import CPG10039
from cpga_analyzer.units import Units

# %%
cpga = CPG10039()

# %%
cpga.add_measurement(DataReader.read("388.CSV"))

# %%
cpga.show_short_pins()
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
cpga.show_short_pins(ignore_error=True)

# %%
cpga.show_pads()
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
cpga.show_short_pads()
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
cpga.show_short_pads(ignore_error=True)
# Out:
# {'B13', 'D13', 'A13', 'C12', 'D12', 'C13', 'B12'}
# error
# {'A5', 'A6', 'C7', 'B6', 'C6', 'B5'}
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
package = Package(cpga, {
    'RF':13,
    'T0':65,
    'T1':61,
    'G0':11,
    'G1':15,
    'G2':66,
    'G3':60,
    'E0':64,
    'E1':62,
    'E2':4,
    'E3':5,
    'E4':6,
    'E5':8,
    'E6':9,
    'E7':17,
    'E8':18,
    'E9':19,
    'E10':20,
    'E11':21,
    'E12':71,
    'E13':70,
    'E14':69,
    'E15':68,
    'E16':67,
    'E17':59,
    'E18':58,
    'E19':57,
    'E20':56,
    'E21':55,
})

# %%
package.show_capacitance_hist()
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'Capacitance Histogram (pF)'}, xlabel='Capacitance (pF)', ylabel='Counts'>)

# %%
package.show_capacitance_map(75 * Units.pF)
# Out:
# (<Figure size 1500x1000 with 2 Axes>,
#  <Axes: title={'center': 'Capacitance Map (pF)'}>)
